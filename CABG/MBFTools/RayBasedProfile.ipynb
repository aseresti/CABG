# %% [markdown]
# # Spatial Correspondance Using Ray Casting of Ischemic and Territory Regions on the Surface of the Myocardium

# %% [markdown]
# Begin by specifying the path to the directory that contains the data required for ray-based analysis. This directory must include the following five files:
#
#  1. MBF Model (VTU format): A volumetric model extracted from the MBF (Myocardial Blood Flow) map.
#
#  2. Basal Slice (VTP format): A slice of the MBF model captured around the base of the myocardium.
#
#  3. Apical Slice (VTP format): A slice of the MBF model representing the apical hemisphere.
#
#  4. Ischemic Region (VTU format): A segmentation of the ischemic region associated with the vessel of interest, also extracted from the MBF map.
#
#  5. MBF Territories Labels (dat format): A text file including the name tag and the number tag of the territories assigned to each branch.
#
# Also, the extracted surface of the MBF map model should be saved into the parent directory of the vessel specific working directory.
#
# After providing the input files, configure the TerritoryTags. These tags indicate myocardial regions downstream of a stenosis, based on the output file MBF_Territories.vtu.
#
# Finally, ensure that the image scale is set appropriately—either in centimeters (cm) or millimeters (mm)—to match the spacing of the input image data. Accurate scaling is essential for proper geometric and spatial interpretation.

# %%
InputFolder = "/Users/ana/Documents/AnahitaSeresti/05_PrePostCABG/RayCasting/SU04A"
slice_apex = f"{InputFolder}/Slice_Apex.vtp"
slice_base = f"{InputFolder}/Slice_Base.vtp"
InputMyocardium = f"{InputFolder}/Myocardium.vtp"
InputMBF = f"{InputFolder}/MBF_Territories.vtu"
InputLV_binarylabelmap = f"{InputFolder}/LV.vtk"


scale = 'cm'

# %%
import os
import vtk
import numpy as np
from vtk.util.numpy_support import vtk_to_numpy, numpy_to_vtk
from utilities import ReadVTUFile, ReadVTPFile, WriteVTPFile, WriteVTUFile, GetCentroid, ThresholdPointsByUpper, LargestConnectedRegion, PrintProgress, ThresholdByUpper, ExtractSurface, ReadVTKFile

NRaySection = 1500
NRaySphere = 40000
NSection = 100


if scale == 'cm':
    Radius = 3.5
    L_Section_Ray = 10
    L_Sphere_Ray = 5
    Ray_Thickness = 0.02
    Base_Cover = 3
    Apex_Cover = 0.3

elif scale == 'mm':
    Radius = 35
    L_Section_Ray = 100
    L_Sphere_Ray = 50
    Ray_Thickness = 0.2
    Base_Cover = 10
    Apex_Cover = 3

else:
    print("provide a proper scale")

# %% [markdown]
# ### Defining necessary functions

# %%
def Line(point1, point2, res):
    line = vtk.vtkLineSource()
    line.SetPoint1(point1)
    line.SetPoint2(point2)
    line.SetResolution(res)
    line.Update()
    
    return line.GetOutput()

def BoldLine(centerline):
    tube_filter = vtk.vtkTubeFilter()
    tube_filter.SetInputData(centerline)
    tube_filter.SetRadius(Ray_Thickness)  # Adjust this value to change thickness
    tube_filter.SetNumberOfSides(50)  # Higher = smoother tube
    tube_filter.CappingOn()  # Close tube ends
    tube_filter.Update()
    
    return tube_filter.GetOutput()

def SliceWPlane(Volume,Origin,Norm):
    plane=vtk.vtkPlane()
    plane.SetOrigin(Origin)
    plane.SetNormal(Norm)
    Slice=vtk.vtkCutter()
    Slice.GenerateTrianglesOff()
    Slice.SetCutFunction(plane)
    Slice.SetInputData(Volume)
    Slice.Update()
    
    return Slice.GetOutput()

def ClipSurfaceWPlane(surface, center, axis, IO = False):
    plane = vtk.vtkPlane()
    plane.SetOrigin(center)
    plane.SetNormal(axis)

    clipper = vtk.vtkClipPolyData()
    clipper.SetInputData(surface)
    clipper.SetClipFunction(plane)
    clipper.GenerateClippedOutputOff()
    if IO:
        clipper.InsideOutOn()
    else:
        clipper.InsideOutOff()
    #clipper.GetOutputInformation(1)
    clipper.Update()

    return clipper.GetOutput()

def ClipVolumeWPlane(volume, center, axis, IO = False):
    plane = vtk.vtkPlane()
    plane.SetOrigin(center)
    plane.SetNormal(axis)

    clipper = vtk.vtkClipDataSet()
    clipper.SetInputData(volume)
    clipper.SetClipFunction(plane)
    if IO:
        clipper.InsideOutOn()
    else:
        clipper.InsideOutOff()

    clipper.Update()

    return clipper.GetOutput()

def RotateVector(ray, normal, angle):
    angle = np.radians(angle)
    normal /= np.linalg.norm(normal)
    ray_rot = (ray*np.cos(angle) + np.cross(normal, ray) * np.sin(angle) + normal * np.dot(normal, ray) * (1 - np.cos(angle)))
    
    return ray_rot

def ProbeFilter(InputData, SourceData):
    probe = vtk.vtkProbeFilter()
    probe.AddInputData(InputData)
    probe.SetSourceData(SourceData)
    probe.Update()
    
    return probe.GetOutput()

def IncreaseResolution(surface, subdivisions = 3):
    subdivide = vtk.vtkLoopSubdivisionFilter()
    subdivide.SetInputData(surface)
    subdivide.SetNumberOfSubdivisions(subdivisions)
    subdivide.Update()

    return subdivide.GetOutput()

def Cylinder(CenterLine):
    tube_filter = vtk.vtkTubeFilter()
    tube_filter.SetInputData(CenterLine)
    tube_filter.SetRadius(Radius)
    tube_filter.SetNumberOfSides(2*NRaySection)
    tube_filter.CappingOff()
    tube_filter.Update()
    
    return tube_filter.GetOutput()

def Hemisphere(apex_centeroid, CL_axis):
    low_res = NRaySphere // 10
    
    sphere = vtk.vtkSphereSource()
    sphere.SetCenter(apex_centeroid)
    sphere.SetRadius(Radius)
    sphere.SetPhiResolution(low_res)
    sphere.SetThetaResolution(low_res)
    sphere.Update()

    Hemisphere = ClipSurfaceWPlane(sphere.GetOutput(), apex_centeroid, CL_axis)
    

    return Hemisphere

def fibonacci_sphere(samples=100):
    """Generates evenly distributed unit vectors over a sphere"""
    points = []
    phi = np.pi * (3. - np.sqrt(5.))  # Golden angle in radians

    for i in range(samples):
        y = 1 - (i / float(samples - 1)) * 2  # y goes from 1 to -1
        radius = np.sqrt(1 - y * y)  # Radius at given y
        theta = phi * i  # Golden angle increment

        x = np.cos(theta) * radius
        z = np.sin(theta) * radius
        points.append([x, y, z])

    return np.array(points)

# %%
SliceApex = ReadVTPFile(slice_apex)
SliceBase = ReadVTPFile(slice_base)

base_centeroid = GetCentroid(SliceBase)
apex_centeroid = GetCentroid(SliceApex)

AnnotationPoints = [base_centeroid, apex_centeroid]

centerline_axis = np.array([AnnotationPoints[1][0] - AnnotationPoints[0][0], 
                                AnnotationPoints[1][1] - AnnotationPoints[0][1], 
                                AnnotationPoints[1][2] - AnnotationPoints[0][2]])

CL_axis = centerline_axis/np.linalg.norm(centerline_axis)

point0 = np.array([AnnotationPoints[0][0] - CL_axis[0]*Base_Cover,
                    AnnotationPoints[0][1] - CL_axis[1]*Base_Cover, 
                    AnnotationPoints[0][2] - CL_axis[2]*Base_Cover])

point1 = np.array([AnnotationPoints[1][0] + CL_axis[0]*Apex_Cover,
                    AnnotationPoints[1][1] + CL_axis[1]*Apex_Cover, 
                    AnnotationPoints[1][2] + CL_axis[2]*Apex_Cover])

# %%
print("--- Extracting the Centerline of the Myocardium")
cl_file = f"{InputFolder}/CenterLine.vtp"
CenterLine = Line(point0, point1, NSection)
WriteVTPFile(cl_file, BoldLine(CenterLine))

InputMBFBase = f"{InputFolder}/UpperMyo.vtu"
InputMBFApex = f"{InputFolder}/ApexMyo.vtu"

Myocardium = ReadVTPFile(InputMyocardium)
ConvertVTU = vtk.vtkAppendFilter()
ConvertVTU.SetInputData(Myocardium)
ConvertVTU.Update()
MyocardiumVTU = ConvertVTU.GetOutput()
UpperMyo = ClipVolumeWPlane(MyocardiumVTU, apex_centeroid, CL_axis, True)
ApexMyo = ClipVolumeWPlane(MyocardiumVTU, apex_centeroid, CL_axis, False)
WriteVTUFile(InputMBFBase, UpperMyo)
WriteVTUFile(InputMBFApex, ApexMyo)

InputMBFBase = f"{InputFolder}/UpperMBF.vtu"
InputMBFApex = f"{InputFolder}/ApexMBF.vtu"


MBF_ = ReadVTUFile(InputMBF)
MBF = ClipVolumeWPlane(MBF_, apex_centeroid, CL_axis, True)
Apex = ClipVolumeWPlane(MBF_, apex_centeroid, CL_axis, False)
WriteVTUFile(InputMBFBase, MBF)
WriteVTUFile(InputMBFApex, Apex)

#LV = ReadVTKFile(InputLV_binarylabelmap)
# Out:
# --- Extracting the Centerline of the Myocardium

# %%
def CastRaysVisualizations(CLPoints):
    
    #>>> Ray Casting across the Myocardium Cylinder 
    slices = vtk.vtkAppendPolyData()

    NRays_sample = 20
    ray_ = np.array([-CL_axis[2], 0, CL_axis[0]])
    res = 50
    angles = np.linspace(0, 360, NRays_sample, endpoint= False)
    Rays = vtk.vtkAppendPolyData()
    Intersection = vtk.vtkAppendPolyData()
    
    for k in range(0,len(CLPoints), int(len(CLPoints)/(NSection/10))):
        MBF_slice = SliceWPlane(MBF, CLPoints[k], CL_axis)
        Myo_slice = SliceWPlane(UpperMyo, CLPoints[k], CL_axis)
        slices.AddInputData(MBF_slice)

        origin = CLPoints[k]
        slice_rays = vtk.vtkAppendPolyData()
        for i in range(NRays_sample):
            ray_new = RotateVector(ray_, CL_axis, angles[i])
            point2 = np.array([origin[0]+ L_Section_Ray*ray_new[0], origin[1] + L_Section_Ray*ray_new[1], origin[2] + L_Section_Ray*ray_new[2]])
            ray = Line(origin, point2, res)
            ray_projected = ProbeFilter(ray, MBF)
            
            mbf_profile = vtk_to_numpy(ray_projected.GetPointData().GetArray("ImageScalars"))
            mbf_values = mbf_profile[mbf_profile > 0]
            average_mbf = np.mean(mbf_values)
            mbf_profile = numpy_to_vtk(np.array([average_mbf for _ in range(ray_projected.GetNumberOfPoints())]))
            
            mbf_profile.SetName("MBFProfile")
            

            territory_profile = vtk_to_numpy(ray_projected.GetPointData().GetArray("TerritoryMaps"))
            territory = territory_profile[territory_profile > 0]
            
            if territory.size > 0:
                territory_tag = np.bincount(territory).argmax()
                territory_profile = numpy_to_vtk(np.array([territory_tag for _ in range(ray_projected.GetNumberOfPoints())]))
            else:
                territory_profile = numpy_to_vtk(np.array([-1 for _ in range(ray_projected.GetNumberOfPoints())]))
            
            territory_profile.SetName("TerritoryProfile")

            ray_projected.GetPointData().AddArray(mbf_profile)
            ray_projected.GetPointData().AddArray(territory_profile)

            intersection_ = vtk.vtkIntersectionPolyDataFilter()
            intersection_.SetInputData(0, Myo_slice)
            intersection_.SetInputData(1, ray_projected)
            intersection_.Update()
            Intersection.AddInputData(intersection_.GetOutput())

            '''
            LV_boundary = numpy_to_vtk(np.array([0 for _ in range(ray_projected.GetNumberOfPoints())]))
            LV_boundary.SetName("LVBoundaries")
            boundary_points = []
            Locator = vtk.vtkPointLocator()
            Locator.SetDataSet(ray_projected)
            Locator.BuildLocator()
            for i in range(Myo_slice.GetNumberOfPoints()):
                point = Myo_slice.GetPoint(i)
                closest_point_id = Locator.FindClosestPoint(point)

                if closest_point_id == -1:
                    continue
                else:
                    boundary_points.append(point)
                    LV_boundary.SetValue(closest_point_id, 1)

            ray_projected.GetPointData().AddArray(LV_boundary)
            '''


            slice_rays.AddInputData(BoldLine(ray_projected))
    
        slice_rays.Update()
    
        Rays.AddInputData(slice_rays.GetOutput())


    #>>> Ray Casting across the Apex Hemisphere
    NRays_sample = 100
    directions = fibonacci_sphere(NRays_sample)
    origin = apex_centeroid
    Rays_ = vtk.vtkAppendPolyData()

    for i in range(NRays_sample):
        ray_new = directions[i]
        point2 = np.array([origin[0]+ L_Sphere_Ray*ray_new[0], origin[1] + L_Sphere_Ray*ray_new[1], origin[2] + L_Sphere_Ray*ray_new[2]])
        ray = Line(origin, point2, res)
        ray_projected = ProbeFilter(ray, MBF)
            
        mbf_profile = vtk_to_numpy(ray_projected.GetPointData().GetArray("ImageScalars"))
        mbf_values = mbf_profile[mbf_profile > 0]
        average_mbf = np.mean(mbf_values)
        mbf_profile = numpy_to_vtk(np.array([average_mbf for _ in range(ray_projected.GetNumberOfPoints())]))
        
        mbf_profile.SetName("MBFProfile")
        

        territory_profile = vtk_to_numpy(ray_projected.GetPointData().GetArray("TerritoryMaps"))
        territory = territory_profile[territory_profile > 0]
        
        if territory.size > 0:
            territory_tag = np.bincount(territory).argmax()
            territory_profile = numpy_to_vtk(np.array([territory_tag for _ in range(ray_projected.GetNumberOfPoints())]))
        else:
            territory_profile = numpy_to_vtk(np.array([-1 for _ in range(ray_projected.GetNumberOfPoints())]))
        
        territory_profile.SetName("TerritoryProfile")

        ray_projected.GetPointData().AddArray(mbf_profile)
        ray_projected.GetPointData().AddArray(territory_profile)

        intersection_ = vtk.vtkIntersectionPolyDataFilter()
        intersection_.SetInputData(0, ApexMyo)
        intersection_.SetInputData(1, ray_projected)
        intersection_.Update()
        Intersection.AddInputData(intersection_.GetOutput())

        '''
        LV_boundary = numpy_to_vtk(np.array([0 for _ in range(ray_projected.GetNumberOfPoints())]))
        LV_boundary.SetName("LVBoundaries")
        boundary_points = []
        Locator = vtk.vtkPointLocator()
        Locator.SetDataSet(ray_projected)
        Locator.BuildLocator()
        for i in range(Myo_slice.GetNumberOfPoints()):
            point = Myo_slice.GetPoint(i)
            closest_point_id = Locator.FindClosestPoint(point)

            if closest_point_id == -1:
                continue
            else:
                boundary_points.append(point)
                LV_boundary.SetValue(closest_point_id, 1)

        ray_projected.GetPointData().AddArray(LV_boundary)
        '''
        Rays_.AddInputData(BoldLine(ray_projected))


    Rays_.Update()
    Rays_ = ClipSurfaceWPlane(Rays_.GetOutput(), point1, CL_axis)
    Rays.AddInputData(Rays_)
    Rays.Update()
    ray_path = f"{InputFolder}/Rays.vtp"
    WriteVTPFile(ray_path, Rays.GetOutput())

    Intersection.Update()
    intersection_path = f"{InputFolder}/Intersection.vtp"
    WriteVTPFile(intersection_path, Intersection.GetOutput())

    slices.Update()
    slice_path = f"{InputFolder}/MyoSlices.vtp"
    WriteVTPFile(slice_path, slices.GetOutput())

# %%
def RayCastingAlongMyocardium(CLPoints):

    NRays = NRaySection
    ray_ = np.array([-CL_axis[2], 0, CL_axis[0]])
    res = 50
    angles = np.linspace(0, 360, NRays, endpoint= False)
    Rays = vtk.vtkAppendPolyData()
    
    print("------ Ray Casting across Sections along Myocardium:")
    progress_old = -1
    for k in range(len(CLPoints)):
        progress_old = PrintProgress(k,len(CLPoints),progress_old)

        origin = CLPoints[k]
        slice_rays = vtk.vtkAppendPolyData()
        
        for i in range(NRays):
            ray_new = RotateVector(ray_, CL_axis, angles[i])
            point2 = np.array([origin[0]+ L_Section_Ray*ray_new[0], origin[1] + L_Section_Ray*ray_new[1], origin[2] + L_Section_Ray*ray_new[2]])
            ray = Line(origin, point2, res)
            ray_projected = ProbeFilter(ray, MBF)
            
            mbf_profile = vtk_to_numpy(ray_projected.GetPointData().GetArray("ImageScalars"))
            mbf_values = mbf_profile[mbf_profile > 0]
            average_mbf = np.mean(mbf_values)
            mbf_profile = numpy_to_vtk(np.array([average_mbf for _ in range(ray_projected.GetNumberOfPoints())]))
            
            mbf_profile.SetName("MBFProfile")
            

            territory_profile = vtk_to_numpy(ray_projected.GetPointData().GetArray("TerritoryMaps"))
            territory = territory_profile[territory_profile > 0]
            
            if territory.size > 0:
                territory_tag = np.bincount(territory).argmax()
                territory_profile = numpy_to_vtk(np.array([territory_tag for _ in range(ray_projected.GetNumberOfPoints())]))
            else:
                territory_profile = numpy_to_vtk(np.array([-1 for _ in range(ray_projected.GetNumberOfPoints())]))
            
            territory_profile.SetName("TerritoryProfile")

            #ray_projected = ProbeFilter(ray, UpperMyo)
            ray_projected.GetPointData().AddArray(mbf_profile)
            ray_projected.GetPointData().AddArray(territory_profile)

            slice_rays.AddInputData(ray_projected)
        slice_rays.Update()
    
        Rays.AddInputData(slice_rays.GetOutput())
    
    Rays.Update()

    return Rays.GetOutput()

# %%
def RayCastingAcrossSphere():
    directions = fibonacci_sphere(NRaySphere)
    origin = apex_centeroid
    Rays_Hemisphere = vtk.vtkAppendPolyData()
    res = 50

    print("------ Ray Casting across the Apex Hemisphere:")
    progress_old = -1
    for i in range(NRaySphere):
        progress = PrintProgress(i, NRaySphere, progress_old)
        progress_old = progress

        ray_new = directions[i]
        point2 = np.array([origin[0]+ L_Sphere_Ray*ray_new[0], origin[1] + L_Sphere_Ray*ray_new[1], origin[2] + L_Sphere_Ray*ray_new[2]])
        ray = Line(origin, point2, res)
        ray_projected = ProbeFilter(ray, MBF)
            
        mbf_profile = vtk_to_numpy(ray_projected.GetPointData().GetArray("ImageScalars"))
        mbf_values = mbf_profile[mbf_profile > 0]
        average_mbf = np.mean(mbf_values)
        mbf_profile = numpy_to_vtk(np.array([average_mbf for _ in range(ray_projected.GetNumberOfPoints())]))
        
        mbf_profile.SetName("MBFProfile")
        

        territory_profile = vtk_to_numpy(ray_projected.GetPointData().GetArray("TerritoryMaps"))
        territory = territory_profile[territory_profile > 0]
        
        if territory.size > 0:
            territory_tag = np.bincount(territory).argmax()
            territory_profile = numpy_to_vtk(np.array([territory_tag for _ in range(ray_projected.GetNumberOfPoints())]))
        else:
            territory_profile = numpy_to_vtk(np.array([-1 for _ in range(ray_projected.GetNumberOfPoints())]))
        
        territory_profile.SetName("TerritoryProfile")

        #ray_projected = ProbeFilter(ray, UpperMyo)
        ray_projected.GetPointData().AddArray(mbf_profile)
        ray_projected.GetPointData().AddArray(territory_profile)

        Rays_Hemisphere.AddInputData(ray_projected)

    Rays_Hemisphere.Update()
    Rays_Hemisphere = ClipSurfaceWPlane(Rays_Hemisphere.GetOutput(), point1, CL_axis)

    return Rays_Hemisphere

# %%
def SpatialCorrespondance(Surface):
    with open(f"{InputFolder}/MBF_Territories_Labels.dat",'r') as infile:
        infile.readline()
        TerritoryLabels=[]
        TerritoryNames = ""
        for LINE in infile:
            line=LINE.split()
            for tag in TerritoryTag:
                if line[1].find(tag)>=0: 
                    TerritoryLabels.append(int(line[0]))
                    TerritoryNames += os.path.splitext(line[1])[0] + "+"
    TerritoryNames = TerritoryNames[:-1]

    ThresholdArray = np.zeros(Surface.GetNumberOfPoints())
    for i in range(Surface.GetNumberOfPoints()):
        if int(Surface.GetPointData().GetArray("TerritoryProfile").GetValue(i)) in TerritoryLabels:
            ThresholdArray[i] = 1
    
    ThresholdArrayVTK = numpy_to_vtk(ThresholdArray, deep=True)
    ThresholdArrayVTK.SetName(f"TerritoryLabels_{TerritoryNames}")
    Surface.GetPointData().AddArray(ThresholdArrayVTK)
    Surface.Modified()

    territory_vtu_ = vtk.vtkAppendFilter()
    territory_vtu_.AddInputData(Surface)
    territory_vtu_.Update()
    territory_vtu = territory_vtu_.GetOutput()
    TerritoryVTU = ThresholdByUpper(territory_vtu, f"TerritoryLabels_{TerritoryNames}", 1)
    TerritoryRegions = ExtractSurface(TerritoryVTU)
    WriteVTPFile(InputFolder + f"/Projected_Territories_{TerritoryNames}.vtp", TerritoryRegions)

    ischemic_vtu_ = vtk.vtkAppendFilter()
    ischemic_vtu_.AddInputData(Surface)
    ischemic_vtu_.Update()
    ischemic_vtu = ischemic_vtu_.GetOutput()
    IschemicVTU = ThresholdByUpper(ischemic_vtu, "IschemicProfile", 1)
    IschemicRegions = ExtractSurface(IschemicVTU)
    ischemic_surface_path = os.path.splitext(os.path.basename(InputIschemic))[0]
    WriteVTPFile(InputFolder + f"/{ischemic_surface_path}.vtp", IschemicRegions)

    TerritoryRegionsPoints=vtk_to_numpy(TerritoryRegions.GetPoints().GetData())
    IschemicRegionsPoints=vtk_to_numpy(IschemicRegions.GetPoints().GetData())

    TerritoryTesselationString=[]
    TerritoryIschemicString=[]
    for i in range(TerritoryRegions.GetNumberOfPoints()): TerritoryTesselationString.append(str(TerritoryRegionsPoints[i]))
    for i in range(IschemicRegions.GetNumberOfPoints()): TerritoryIschemicString.append(str(IschemicRegionsPoints[i]))
    TotalPointsString=TerritoryTesselationString+TerritoryIschemicString
    UniquePointsString=set(TotalPointsString)
    OverlapCounter=len(TotalPointsString)-len(UniquePointsString)

    DiceScore = (2*OverlapCounter)/(TerritoryRegions.GetNumberOfPoints() + IschemicRegions.GetNumberOfPoints())

    OverlapTag_Ischemic = np.zeros(IschemicRegions.GetNumberOfPoints())
    point_locator = vtk.vtkPointLocator()
    point_locator.SetDataSet(TerritoryRegions)
    point_locator.BuildLocator()

    tolerance = 0.01
    dist2 = vtk.reference(0.0)
    Mean_dist = 0
    counter = 0
    for i in range(IschemicRegions.GetNumberOfPoints()):
        point = IschemicRegions.GetPoint(i)
        closest_point_id = point_locator.FindClosestPointWithinRadius(tolerance, point, dist2)
        if closest_point_id != -1:
            OverlapTag_Ischemic[i] = 1
        else:
            counter += 1
            point_ = TerritoryRegions.GetPoint(i)
            Mean_dist += vtk.vtkMath.Distance2BetweenPoints(point, point_) ** 0.5
        
    Mean_dist /= counter

    return TerritoryRegions, IschemicRegions, DiceScore, Mean_dist, TerritoryNames

# %% [markdown]
# ### Implementing the Method

# %%
print("--- Visualizing Ray Casting")
CLPoints = CenterLine.GetPoints()
CLPointsArray = np.array([CLPoints.GetPoint(i) for i in range(CLPoints.GetNumberOfPoints())])
CastRaysVisualizations(CLPointsArray)
# Out:
# --- Visualizing Ray Casting
# /usr/local/anaconda3/envs/vtkfenics/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/anaconda3/envs/vtkfenics/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-25 21:09:19.847 (95934.682s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.848 (95934.682s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.848 (95934.682s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab19ac80): No points to subdivide
# 2025-06-25 21:09:19.848 (95934.682s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.855 (95934.689s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.855 (95934.689s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.855 (95934.689s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1a5ef0): No points to subdivide
# 2025-06-25 21:09:19.855 (95934.689s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.863 (95934.697s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.863 (95934.698s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.863 (95934.698s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f6341f0): No points to subdivide
# 2025-06-25 21:09:19.863 (95934.698s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.871 (95934.706s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.871 (95934.706s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.871 (95934.706s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1a9af0): No points to subdivide
# 2025-06-25 21:09:19.871 (95934.706s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.879 (95934.714s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.880 (95934.714s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.880 (95934.714s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a7f5c90): No points to subdivide
# 2025-06-25 21:09:19.880 (95934.714s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.890 (95934.724s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.890 (95934.724s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.890 (95934.724s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab1b2960): No points to subdivide
# 2025-06-25 21:09:19.890 (95934.724s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.905 (95934.739s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.905 (95934.739s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.905 (95934.739s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a7f8c40): No points to subdivide
# 2025-06-25 21:09:19.905 (95934.739s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.923 (95934.757s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.923 (95934.758s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.923 (95934.758s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a76d310): No points to subdivide
# 2025-06-25 21:09:19.923 (95934.758s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.935 (95934.770s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.936 (95934.770s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.936 (95934.770s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a7d2b20): No points to subdivide
# 2025-06-25 21:09:19.936 (95934.770s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.945 (95934.780s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.945 (95934.780s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.946 (95934.780s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a7ac040): No points to subdivide
# 2025-06-25 21:09:19.946 (95934.780s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.956 (95934.790s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.956 (95934.790s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.956 (95934.790s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f6c38e0): No points to subdivide
# 2025-06-25 21:09:19.956 (95934.790s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.965 (95934.800s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.966 (95934.800s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.966 (95934.800s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f6a82d0): No points to subdivide
# 2025-06-25 21:09:19.966 (95934.800s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.975 (95934.810s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.976 (95934.810s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.976 (95934.810s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1c99f0): No points to subdivide
# 2025-06-25 21:09:19.976 (95934.810s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.985 (95934.819s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.985 (95934.820s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.985 (95934.820s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e14f7b0): No points to subdivide
# 2025-06-25 21:09:19.985 (95934.820s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:19.993 (95934.827s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.993 (95934.827s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:19.993 (95934.827s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a7ada10): No points to subdivide
# 2025-06-25 21:09:19.993 (95934.827s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.000 (95934.835s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.000 (95934.835s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.000 (95934.835s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a74c270): No points to subdivide
# 2025-06-25 21:09:20.001 (95934.835s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.008 (95934.842s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.008 (95934.842s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.008 (95934.843s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e158120): No points to subdivide
# 2025-06-25 21:09:20.008 (95934.843s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.016 (95934.851s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.016 (95934.851s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.016 (95934.851s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a7a7560): No points to subdivide
# 2025-06-25 21:09:20.016 (95934.851s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.026 (95934.861s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.027 (95934.861s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.027 (95934.861s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a76e360): No points to subdivide
# 2025-06-25 21:09:20.027 (95934.861s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.035 (95934.869s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.035 (95934.869s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.035 (95934.869s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a7c1c00): No points to subdivide
# 2025-06-25 21:09:20.035 (95934.869s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.204 (95935.039s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.205 (95935.039s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.205 (95935.039s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab11faa0): No points to subdivide
# 2025-06-25 21:09:20.205 (95935.039s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.211 (95935.045s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.211 (95935.045s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.211 (95935.046s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab12b3f0): No points to subdivide
# 2025-06-25 21:09:20.211 (95935.046s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.219 (95935.054s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.219 (95935.054s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.220 (95935.054s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a7a55b0): No points to subdivide
# 2025-06-25 21:09:20.220 (95935.054s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.228 (95935.062s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.228 (95935.062s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.228 (95935.062s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a7e4d10): No points to subdivide
# 2025-06-25 21:09:20.228 (95935.062s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.236 (95935.071s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.236 (95935.071s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.237 (95935.071s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f6b7550): No points to subdivide
# 2025-06-25 21:09:20.237 (95935.071s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.246 (95935.081s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.246 (95935.081s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.247 (95935.081s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e10c240): No points to subdivide
# 2025-06-25 21:09:20.247 (95935.081s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.258 (95935.092s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.258 (95935.093s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.258 (95935.093s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1af590): No points to subdivide
# 2025-06-25 21:09:20.258 (95935.093s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.268 (95935.102s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.268 (95935.102s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.268 (95935.102s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a7e61d0): No points to subdivide
# 2025-06-25 21:09:20.268 (95935.102s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.276 (95935.111s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.276 (95935.111s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.276 (95935.111s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1b2f90): No points to subdivide
# 2025-06-25 21:09:20.276 (95935.111s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.284 (95935.119s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.284 (95935.119s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.284 (95935.119s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab12f570): No points to subdivide
# 2025-06-25 21:09:20.284 (95935.119s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.291 (95935.126s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.291 (95935.126s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.291 (95935.126s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab13a1d0): No points to subdivide
# 2025-06-25 21:09:20.291 (95935.126s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.298 (95935.133s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.299 (95935.133s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.299 (95935.133s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab141600): No points to subdivide
# 2025-06-25 21:09:20.299 (95935.133s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.306 (95935.140s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.306 (95935.140s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.306 (95935.140s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab148a30): No points to subdivide
# 2025-06-25 21:09:20.306 (95935.140s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.312 (95935.146s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.312 (95935.147s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.312 (95935.147s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab14fe60): No points to subdivide
# 2025-06-25 21:09:20.312 (95935.147s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.319 (95935.154s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.319 (95935.154s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.319 (95935.154s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab152fb0): No points to subdivide
# 2025-06-25 21:09:20.319 (95935.154s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.327 (95935.161s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.328 (95935.162s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.328 (95935.162s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e17b720): No points to subdivide
# 2025-06-25 21:09:20.328 (95935.162s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.336 (95935.170s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.336 (95935.170s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.336 (95935.170s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1bf1d0): No points to subdivide
# 2025-06-25 21:09:20.336 (95935.170s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.342 (95935.177s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.343 (95935.177s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.343 (95935.177s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1eee20): No points to subdivide
# 2025-06-25 21:09:20.343 (95935.177s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.350 (95935.184s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.350 (95935.184s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.350 (95935.184s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e186890): No points to subdivide
# 2025-06-25 21:09:20.350 (95935.184s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.356 (95935.191s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.357 (95935.191s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.357 (95935.191s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f689c00): No points to subdivide
# 2025-06-25 21:09:20.357 (95935.191s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.571 (95935.405s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.571 (95935.405s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.571 (95935.405s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f684a00): No points to subdivide
# 2025-06-25 21:09:20.571 (95935.405s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.576 (95935.411s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.577 (95935.411s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.577 (95935.411s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f609d20): No points to subdivide
# 2025-06-25 21:09:20.577 (95935.411s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.583 (95935.417s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.583 (95935.417s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.583 (95935.417s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f6cb5c0): No points to subdivide
# 2025-06-25 21:09:20.583 (95935.417s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.588 (95935.423s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.589 (95935.423s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.589 (95935.423s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f61fcd0): No points to subdivide
# 2025-06-25 21:09:20.589 (95935.423s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.595 (95935.429s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.595 (95935.430s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.595 (95935.430s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f6d7770): No points to subdivide
# 2025-06-25 21:09:20.595 (95935.430s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.602 (95935.436s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.602 (95935.436s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.602 (95935.436s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1c5680): No points to subdivide
# 2025-06-25 21:09:20.602 (95935.436s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.624 (95935.459s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.626 (95935.460s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.630 (95935.464s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab040150): No points to subdivide
# 2025-06-25 21:09:20.630 (95935.465s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.643 (95935.478s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.644 (95935.478s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.644 (95935.478s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e14aa10): No points to subdivide
# 2025-06-25 21:09:20.644 (95935.478s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.650 (95935.485s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.650 (95935.485s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.651 (95935.485s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a7c6800): No points to subdivide
# 2025-06-25 21:09:20.651 (95935.485s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.657 (95935.491s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.657 (95935.491s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.657 (95935.491s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a7d13e0): No points to subdivide
# 2025-06-25 21:09:20.657 (95935.491s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.664 (95935.499s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.664 (95935.499s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.664 (95935.499s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f63b380): No points to subdivide
# 2025-06-25 21:09:20.664 (95935.499s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.671 (95935.505s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.671 (95935.505s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.671 (95935.506s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f694d30): No points to subdivide
# 2025-06-25 21:09:20.671 (95935.506s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.678 (95935.512s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.678 (95935.512s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.678 (95935.513s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f69c160): No points to subdivide
# 2025-06-25 21:09:20.678 (95935.513s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.685 (95935.519s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.685 (95935.520s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.685 (95935.520s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab120d00): No points to subdivide
# 2025-06-25 21:09:20.685 (95935.520s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.692 (95935.526s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.692 (95935.526s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.692 (95935.526s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab1ac3d0): No points to subdivide
# 2025-06-25 21:09:20.692 (95935.526s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.699 (95935.534s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.699 (95935.534s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.700 (95935.534s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e154690): No points to subdivide
# 2025-06-25 21:09:20.700 (95935.534s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.706 (95935.540s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.706 (95935.540s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.706 (95935.541s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e15e620): No points to subdivide
# 2025-06-25 21:09:20.706 (95935.541s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.712 (95935.546s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.712 (95935.546s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.712 (95935.546s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e165b50): No points to subdivide
# 2025-06-25 21:09:20.712 (95935.546s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.718 (95935.553s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.718 (95935.553s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.718 (95935.553s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e16cf80): No points to subdivide
# 2025-06-25 21:09:20.718 (95935.553s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.724 (95935.558s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.724 (95935.559s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.724 (95935.559s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1743b0): No points to subdivide
# 2025-06-25 21:09:20.724 (95935.559s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.959 (95935.793s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.959 (95935.793s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.959 (95935.794s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e159ba0): No points to subdivide
# 2025-06-25 21:09:20.959 (95935.794s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.964 (95935.799s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.965 (95935.799s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.965 (95935.799s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f686130): No points to subdivide
# 2025-06-25 21:09:20.965 (95935.799s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.970 (95935.804s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.970 (95935.804s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.970 (95935.805s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f604270): No points to subdivide
# 2025-06-25 21:09:20.970 (95935.805s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.975 (95935.810s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.975 (95935.810s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.975 (95935.810s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f6d9ec0): No points to subdivide
# 2025-06-25 21:09:20.975 (95935.810s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.981 (95935.815s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.981 (95935.815s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.981 (95935.816s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e148c80): No points to subdivide
# 2025-06-25 21:09:20.981 (95935.816s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.986 (95935.821s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.987 (95935.821s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.987 (95935.821s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1ac300): No points to subdivide
# 2025-06-25 21:09:20.987 (95935.821s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.992 (95935.826s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.992 (95935.826s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.992 (95935.827s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e13dce0): No points to subdivide
# 2025-06-25 21:09:20.992 (95935.827s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:20.998 (95935.833s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.999 (95935.833s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:20.999 (95935.833s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f62e290): No points to subdivide
# 2025-06-25 21:09:20.999 (95935.833s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.004 (95935.839s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.005 (95935.839s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.005 (95935.839s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f6f82e0): No points to subdivide
# 2025-06-25 21:09:21.005 (95935.839s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.010 (95935.844s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.010 (95935.845s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.010 (95935.845s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f6ee170): No points to subdivide
# 2025-06-25 21:09:21.010 (95935.845s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.016 (95935.851s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.016 (95935.851s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.016 (95935.851s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1b09a0): No points to subdivide
# 2025-06-25 21:09:21.016 (95935.851s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.022 (95935.856s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.022 (95935.857s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.022 (95935.857s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1c3700): No points to subdivide
# 2025-06-25 21:09:21.022 (95935.857s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.028 (95935.862s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.028 (95935.862s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.028 (95935.862s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1d3b60): No points to subdivide
# 2025-06-25 21:09:21.028 (95935.862s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.033 (95935.868s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.034 (95935.868s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.034 (95935.868s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1db000): No points to subdivide
# 2025-06-25 21:09:21.034 (95935.868s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.039 (95935.873s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.039 (95935.873s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.039 (95935.873s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1e2430): No points to subdivide
# 2025-06-25 21:09:21.039 (95935.873s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.045 (95935.879s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.045 (95935.879s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.045 (95935.880s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e1e9860): No points to subdivide
# 2025-06-25 21:09:21.045 (95935.880s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.051 (95935.885s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.051 (95935.885s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.051 (95935.885s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f643530): No points to subdivide
# 2025-06-25 21:09:21.051 (95935.885s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.056 (95935.890s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.056 (95935.890s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.056 (95935.891s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f64e1e0): No points to subdivide
# 2025-06-25 21:09:21.056 (95935.891s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.061 (95935.895s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.061 (95935.896s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.061 (95935.896s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3f655610): No points to subdivide
# 2025-06-25 21:09:21.061 (95935.896s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.067 (95935.901s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.067 (95935.901s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.067 (95935.902s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c6a7c3740): No points to subdivide
# 2025-06-25 21:09:21.067 (95935.902s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.301 (95936.135s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.301 (95936.135s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.301 (95936.136s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab1b3c30): No points to subdivide
# 2025-06-25 21:09:21.301 (95936.136s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.306 (95936.141s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.306 (95936.141s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.307 (95936.141s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab1bbd50): No points to subdivide
# 2025-06-25 21:09:21.307 (95936.141s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.311 (95936.146s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.312 (95936.146s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.312 (95936.146s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8cab1c3180): No points to subdivide
# 2025-06-25 21:09:21.312 (95936.146s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.317 (95936.151s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.317 (95936.152s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.317 (95936.152s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e16aa20): No points to subdivide
# 2025-06-25 21:09:21.317 (95936.152s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.323 (95936.158s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.323 (95936.158s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.324 (95936.158s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e161150): No points to subdivide
# 2025-06-25 21:09:21.324 (95936.158s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# 2025-06-25 21:09:21.332 (95936.166s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.332 (95936.166s) [         1483757]            vtkMath.cxx:797   WARN| vtkMath::Jacobi: Error extracting eigenfunctions
# 2025-06-25 21:09:21.332 (95936.166s) [         1483757]    vtkPointLocator.cxx:868    ERR| vtkPointLocator (0x7f8c3e137570): No points to subdivide
# 2025-06-25 21:09:21.332 (95936.166s) [         1483757]vtkIntersectionPolyData:2410  WARN| No Intersection between objects
# ...
# 2025-06-25 21:09:22.788 (95937.622s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e4be360): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e423fa0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.792 (95937.627s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f658dd0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.797 (95937.632s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e4b15a0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e4d97a0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.802 (95937.637s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e75d230): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c6a7c8ad0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.807 (95937.641s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7a0870): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e7ebad0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.812 (95937.646s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7ebbc0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e70e5f0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.816 (95937.651s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7ebbc0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e75a6b0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.821 (95937.656s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c6a7c8ad0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e716210) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.826 (95937.661s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e4be360): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e4d97a0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.832 (95937.666s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f6c51f0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.837 (95937.672s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f0eae60) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.843 (95937.677s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f0f5d20) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.848 (95937.683s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7328f0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c6a7c8ad0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.853 (95937.687s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7ebbc0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e70cc20) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.858 (95937.692s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f658dd0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.863 (95937.697s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f0c1e40) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.870 (95937.705s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e4e52f0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e4b15a0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.874 (95937.709s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7cdf70): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e7c1a50) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.879 (95937.713s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7eb720): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e741de0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.885 (95937.720s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7d1ca0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e77f8b0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.889 (95937.724s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e757160): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e7caca0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.895 (95937.729s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e757160): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e71f7e0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.900 (95937.734s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f6c51f0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.904 (95937.739s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e757160): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e70cea0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.910 (95937.745s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e70cea0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e7c1780) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.915 (95937.749s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c4b0e9050): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c4b0bb6f0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.920 (95937.754s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c4b0e9050): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8cab1f35c0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.924 (95937.759s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c4b0e9050): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8cab131de0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.929 (95937.763s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7eb720): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e7cd4d0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.935 (95937.769s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e77f9e0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e715c80) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.939 (95937.774s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7ebbc0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e71b1b0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.944 (95937.779s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e441060): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e4f3430) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.949 (95937.784s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f658dd0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.953 (95937.788s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f0c1bc0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.958 (95937.792s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f089e50) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.962 (95937.797s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f07b130) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.967 (95937.801s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f080600) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.972 (95937.807s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f083030) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.976 (95937.811s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f08f080) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.981 (95937.816s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7eb720): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e757160) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.986 (95937.820s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f6c51f0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.990 (95937.824s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f0d2e60) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:22.995 (95937.830s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f08f2d0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:23.001 (95937.835s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7f90f0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e757160) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:23.005 (95937.840s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c4b0e9050): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c4b0bb6f0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:23.011 (95937.845s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c4b0e9050): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8cab1d19b0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:23.016 (95937.850s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7f9fc0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e757160) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:23.021 (95937.855s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e78cab0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e72e0f0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:23.025 (95937.859s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3f6f51b0): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3f658dd0) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:23.029 (95937.864s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e7cb310): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e7c1520) is of type vtkUnstructuredGrid, but a vtkPolyData is required.
# 2025-06-25 21:09:23.034 (95937.869s) [         1483757]vtkDemandDrivenPipeline:754    ERR| vtkCompositeDataPipeline (0x7f8c3e757160): Input for connection index 0 on input port index 0 for algorithm vtkIntersectionPolyDataFilter (0x7f8c3e7fe180) is of type vtkUnstructuredGrid, but a vtkPolyData is required.

# %% [markdown]
# ## Verify Geometry and Coverage
# Before proceeding, double-check the visuals:
#
#  - Confirm that the centerline extends along the myocardium as expected.
#
#  - Ensure that the rays generated from each centerline point adequately cover the myocardial wall in all directions.

# %%
print("--- Ray Casting Across the Myocardium")
Rays_Myocardium = RayCastingAlongMyocardium(CLPointsArray)
# Out:
# --- Ray Casting Across the Myocardium
# ------ Ray Casting across Sections along Myocardium:
#     Progress: 0%
#     Progress: 10%
#     Progress: 20%
#     Progress: 30%
#     Progress: 40%
#     Progress: 50%
#     Progress: 60%
#     Progress: 70%
#     Progress: 80%
#     Progress: 90%
#     Progress: 100%

# %%
WriteVTPFile(f"{InputFolder}/Rays_Myocardium.vtp", Rays_Myocardium)

# %%
Rays_Hemisphere = RayCastingAcrossSphere()
# Out:
# ------ Ray Casting across the Apex Hemisphere:
#     Progress: 0%
#     Progress: 10%
#     Progress: 20%
#     Progress: 30%
#     Progress: 40%
#     Progress: 50%
#     Progress: 60%
#     Progress: 70%
#     Progress: 80%
#     Progress: 90%
#     Progress: 100%
#     Progress: 100%

# %%
WriteVTPFile(f"{InputFolder}/Rays_Hemisphere.vtp", Rays_Hemisphere)

# %%
OutputSurface = vtk.vtkAppendPolyData()
OutputSurface.AddInputData(Rays_Myocardium)
OutputSurface.AddInputData(Rays_Hemisphere)
OutputSurface.Update()

OutputVolume_ = vtk.vtkAppendFilter()
OutputVolume_.AddInputData(OutputSurface.GetOutput())
OutputVolume_.Update()
OutputVolume = OutputVolume_.GetOutput()

# %%
MyocardiumSurface = ReadVTPFile(f"{InputFolder}/../MyocardiumSurface.vtp")

# %%
IschemicProfile_Array = vtk.vtkFloatArray()
IschemicProfile_Array.SetName("IschemicProfile")
IschemicProfile_Array.SetNumberOfComponents(1)
IschemicProfile_Array.SetNumberOfTuples(MyocardiumSurface.GetNumberOfPoints())

TerritoryProfile_Array = vtk.vtkFloatArray()
TerritoryProfile_Array.SetName("TerritoryProfile")
TerritoryProfile_Array.SetNumberOfComponents(1)
TerritoryProfile_Array.SetNumberOfTuples(MyocardiumSurface.GetNumberOfPoints())

Rays_Output = OutputVolume
Rays_ischemic = Rays_Output.GetPointData().GetArray("IschemicProfile")
Rays_territory = Rays_Output.GetPointData().GetArray("TerritoryProfile")

Locator = vtk.vtkPointLocator()
Locator.SetDataSet(Rays_Output)
Locator.BuildLocator()

tolerance = 1
dist2 = vtk.reference(0.0)


for i in range(MyocardiumSurface.GetNumberOfPoints()):
    point = MyocardiumSurface.GetPoint(i)
    closest_point_id = Locator.FindClosestPoint(point)
    
    
    #IschemicProfile_Array.SetValue(i, Rays_ischemic.GetValue(closest_point_id))
    #TerritoryProfile_Array.SetValue(i, Rays_territory.GetValue(closest_point_id))
    
    if closest_point_id == -1:
        IschemicProfile_Array.SetValue(i, 0)
        TerritoryProfile_Array.SetValue(i, -1)
    else:
        IschemicProfile_Array.SetValue(i, Rays_ischemic.GetValue(closest_point_id))
        TerritoryProfile_Array.SetValue(i, Rays_territory.GetValue(closest_point_id))
    

MyocardiumSurface.GetPointData().AddArray(IschemicProfile_Array)
MyocardiumSurface.GetPointData().AddArray(TerritoryProfile_Array)

WriteVTPFile(f"{InputFolder}/MyocardiumSurface.vtp", MyocardiumSurface)

# %%
TerritoryRegions, IschemicRegions, DiceScore, SpatialDifference, TerritoryNames = SpatialCorrespondance(MyocardiumSurface)
DiceScore = int(DiceScore*100)/100
print("Dice-score:", DiceScore)

if scale == 'cm':
    SpatialDifference = int(SpatialDifference*100)/100
elif scale == 'mm':
    SpatialDifference = int(SpatialDifference)/100
    
print("Spatial Difference between Non-overlapping points: ", SpatialDifference, "cm")
# Out:
# Dice-score: 0.74
# Spatial Difference between Non-overlapping points:  13.27 cm

# %%
def SurfaceAreaCalculator(Surface):
    Mass = vtk.vtkMassProperties()
    Mass.AddInputData(Surface)
    Mass.Update()
    return Mass.GetSurfaceArea()

SurfaceArea = SurfaceAreaCalculator(MyocardiumSurface)

if scale == 'cm':
    SurfaceArea_Myocardium = int(SurfaceArea*100)/100
elif scale == 'mm':
    SurfaceArea_Myocardium = int(SurfaceArea)/100
    
print("Surface Area of the Myocardium: ", SurfaceArea_Myocardium, "cm^2")
# Out:
# Surface Area of the Myocardium:  169.08 cm^2

# %%
SurfaceArea = SurfaceAreaCalculator(TerritoryRegions)

if scale == 'cm':
    SurfaceArea_Territory = int(SurfaceArea*100)/100
elif scale == 'mm':
    SurfaceArea_Territory = int(SurfaceArea)/100

print("Territory Regions Surface Area:", SurfaceArea_Territory, "cm^2")


SurfaceArea = SurfaceAreaCalculator(IschemicRegions)

if scale == 'cm':
    SurfaceArea_Ischemic = int(SurfaceArea*100)/100
elif scale == 'mm':
    SurfaceArea_Ischemic = int(SurfaceArea)/100

print("Ischemic Regions Surface Area:", SurfaceArea_Ischemic, "cm^2")
# Out:
# Territory Regions Surface Area: 39.97 cm^2
# Ischemic Regions Surface Area: 57.18 cm^2

# %%
ofile_path = InputFolder + "/RayBasedProfileResults.dat"
with open(ofile_path, 'w') as ofile:
    ofile.writelines(f"Selected Territory Regions: {TerritoryNames}\n")
    ofile.writelines(f"Myocardium Surface (cm\u00b2): {SurfaceArea_Myocardium}\n")
    ofile.writelines(f"Territory Regions Surface Area (cm\u00b2): {SurfaceArea_Territory}\n")
    ofile.writelines(f"Ischemic Regions Surface Area (cm\u00b2): {SurfaceArea_Ischemic}\n")
    ofile.writelines(f"Dice-Score: {DiceScore}\n")
    ofile.writelines(f"Spatial Difference (cm): {SpatialDifference}\n")
